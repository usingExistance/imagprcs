# %%
import cv2
from skimage import io
img = io.imread('matthias-heil-PozYb57vV38-unsplash.jpg')
from matplotlib import pyplot as plot
image =cv2.imread('matthias-heil-PozYb57vV38-unsplash.jpg')
plot.hist(image.ravel(),256)
plot.show()
io.imshow(img)
